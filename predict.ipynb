# %%
import numpy as np
import pandas as pd
import cv2
import pytesseract
from glob import glob
import spacy
from spacy import displacy
import re
import string

# %% [markdown]
# # Cleansing

# %%
# help function to clean up you text
def cleanText(text: str) -> str:
    """
    Designed for:
    -------------
    removement of  whitespaces and special characters from source text
    Input:
    ------
    str to preprocess
    Output:
    -------
    clean str
    """
    whitespace = string.whitespace
    punctuation = '!#$%&\'()*+/:;<=>?[\\]^`{|}~'
    table_whitespace = str.maketrans('', '', whitespace)
    table_puctuation = str.maketrans('', '', punctuation)
    text = str(text)
    text = text.lower()
    removeWhitespace = text.translate(table_whitespace)
    removePunctuation = removeWhitespace.translate(table_puctuation)
    return str(removePunctuation)

# %%
# load NER model 
modelNER = spacy.load('./output/model-best/')

# %%
# load image
img = cv2.imread('./data/6.jpg')
#cv2.imshow(img)
#cv2.waitKey(1)
#cv2.destroyAllWindows()

# extract data with pytesseract
rawData = pytesseract.image_to_data(img)
# convert to a pd dataframe
rawList = list(map(lambda x: x.split('\t'), rawData.split('\n')))
df = pd.DataFrame(rawList[1:], columns=rawList[0])
df.dropna(inplace=True)
df['text'] = df['text'].apply(cleanText)
df_clean = df.query('text != "" ')
content = " ".join([word for word in df_clean['text']])

# get predictions
doc = modelNER(content)
displacy.serve(doc, style="ent", auto_select_port=True)
# Out:
# /Users/antonskvarskij/OCR_projects/Document_scanner/venv/lib/python3.9/site-packages/spacy/util.py:1817: UserWarning: [W124] 0.0.0.0:5000 is already in use, using the nearest available port 5001 as an alternative.
#   warnings.warn(Warnings.W124.format(host=host, port=start, serve_port=port))
# /Users/antonskvarskij/OCR_projects/Document_scanner/venv/lib/python3.9/site-packages/spacy/displacy/__init__.py:106: UserWarning: [W011] It looks like you're calling displacy.serve from within a Jupyter notebook or a similar environment. This likely means you're already running a local web server, so there's no need to make displaCy start another one. Instead, you should be able to replace displacy.serve with displacy.render to show the visualization.
#   warnings.warn(Warnings.W011)
# <span class="tex2jax_ignore"><!DOCTYPE html>
# <html lang="en">
#     <head>
#         <title>displaCy</title>
#     </head>
#
#     <body style="font-size: 16px; font-family: -apple-system, BlinkMacSystemFont, 'Segoe UI', Helvetica, Arial, sans-serif, 'Apple Color Emoji', 'Segoe UI Emoji', 'Segoe UI Symbol'; padding: 4rem 2rem; direction: ltr">
# <figure style="margin-bottom: 6rem">
# <div class="entities" style="line-height: 2.5; direction: ltr">cell
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8099948528
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-PHONE</span>
# </mark>
#  ga 8466045457 email
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     seosrikantht@gmail.com
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-EMAIL</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thathineni
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     srikanth
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-NAME</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-DES</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     advisor
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-DES</span>
# </mark>
#  agent code no. 0316164y
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     life
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">B-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     insurance
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     corporation
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     of
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     india
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-ORG</span>
# </mark>
#  br. off. lic office, trimulgherry, sec’bad - 500 016. add. borabanda, hyderabad - 500 018.
# <mark class="entity" style="background: #ddd; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     lictsrikant8099948528.blogspot.in
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">I-EMAIL</span>
# </mark>
# , interviewsinhyderabad.blogspot.in facebook.comlictsrikant8099948528, facebook.comthathineni.srikanth.9 promote your business online pybo</div>
# </figure>
# </body>
# </html></span>
# Using the 'ent' visualizer
# Serving on http://0.0.0.0:5001 ...
# 127.0.0.1 - - [05/Dec/2023 22:18:43] "GET / HTTP/1.1" 200 6203
# 127.0.0.1 - - [05/Dec/2023 22:18:43] "GET /favicon.ico HTTP/1.1" 200 6203
# Shutting down server on port 5001.

# %%
docjson = doc.to_json()
docjson.keys()
# Out:
# dict_keys(['text', 'ents', 'tokens'])

# %%
doc_text = docjson['text']
data_tokens = pd.DataFrame(docjson['tokens'])
data_tokens['text'] = data_tokens[['start', 'end']].apply(
    lambda x: doc_text[x[0]:x[1]], axis=1)
# Out:
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/2001692833.py:4: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   lambda x: doc_text[x[0]:x[1]], axis=1)

# %%
data_tokens.head()
# Out:
#    id  start  end        text
# 0   0      0    4        cell
# 1   1      5   15  8099948528
# 2   2     16   18          ga
# 3   3     19   29  8466045457
# 4   4     30   35       email

# %%
dataframe_tokens = pd.merge(data_tokens, 
              pd.DataFrame(docjson['ents'])[['start', 'label']], 
              how='left', 
              on='start')

# %%
dataframe_tokens.fillna('O', inplace=True)

# %%
dataframe_tokens.columns = ['id', 'start', 'end', 'token', 'label']

# %%
dataframe_tokens.head(10)
# Out:
#    id  start  end                  token    label
# 0   0      0    4                   cell        O
# 1   1      5   15             8099948528  B-PHONE
# 2   2     16   18                     ga        O
# 3   3     19   29             8466045457        O
# 4   4     30   35                  email        O
# 5   5     36   57  lictsrikant@gmail.com  B-EMAIL
# 6   6     58   62                   life    B-ORG
# 7   7     63   72              insurance    I-ORG
# 8   8     73   84            corporation    I-ORG
# 9   9     85   87                     of    I-ORG

# %%
df_clean['end'] = df_clean['text'].apply(lambda x: len(x) + 1).cumsum() - 1
df_clean['start'] = df_clean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)

df_clean.head(10)
# Out:
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/1659152718.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['end'] = df_clean['text'].apply(lambda x: len(x) + 1).cumsum() - 1
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/1659152718.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   df_clean['start'] = df_clean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/1659152718.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_clean['start'] = df_clean[['text', 'end']].apply(lambda x: x[1] - len(x[0]), axis=1)
#    level page_num block_num par_num line_num word_num left  top width height  \
# 12     5        1         3       1        1        1  722   53    64     28
# 14     5        1         3       1        1        3  822   53   203     28
# 17     5        1         3       2        1        1   55   55    85     89
# 18     5        1         3       2        1        2  822   95   203     28
# 20     5        1         3       2        2        1  593  136    93     25
# 22     5        1         3       2        2        3  709  136   316     31
# 25     5        1         3       3        1        1   46  170    33     14
# 26     5        1         3       3        1        2   85  151    92     42
# 27     5        1         3       3        1        3  183  170   117     14
# 28     5        1         3       3        1        4  306  170    20     14
#
#          conf                   text  end  start
# 12  93.027191                   cell    4      0
# 14  96.644051             8099948528   15      5
# 17  47.185547                     ga   18     16
# 18  96.643845             8466045457   29     19
# 20  89.289780                  email   35     30
# 22  86.249245  lictsrikant@gmail.com   57     36
# 25  96.406654                   life   62     58
# 26  95.806709              insurance   72     63
# 27  96.909729            corporation   84     73
# 28  96.172005                     of   87     85

# %%
data_info = pd.merge(df_clean, 
         dataframe_tokens[['start', 'token', 'label']], 
         how='inner', 
         on='start')

data_info.tail(10)
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 39     5        1         6       3        1        6  495  474    53     21
# 40     5        1         6       3        2        1   46  506   430     27
# 41     5        1         6       3        2        2  488  506   429     27
# 42     5        1         6       3        3        1   44  539   472     25
# 43     5        1         6       3        3        2  526  539   443     22
# 44     5        1         6       3        4        1   46  571   106     21
# 45     5        1         6       3        4        2  161  576    56     22
# 46     5        1         6       3        4        3  226  571   111     21
# 47     5        1         6       3        4        4  347  571    74     21
# 48     5        1         6       3        4        5  432  571    96     27
#
#          conf                                text  end  start  \
# 39  96.027008                                018.  305    301
# 40  85.618164  lictsrikant8099948528.blogspot.in,  340    306
# 41  89.912384   interviewsinhyderabad.blogspot.in  374    341
# 42  87.967415  facebook.comlictsrikant8099948528,  409    375
# 43  90.545654   facebook.comthathineni.srikanth.9  443    410
# 44  96.344551                             promote  451    444
# 45  95.835091                                your  456    452
# 46  96.409111                            business  465    457
# 47  93.162605                              online  472    466
# 48  92.261208                                pybo  477    473
#
#                                 token    label
# 39                                018        O
# 40  lictsrikant8099948528.blogspot.in  I-EMAIL
# 41  interviewsinhyderabad.blogspot.in        O
# 42  facebook.comlictsrikant8099948528        O
# 43  facebook.comthathineni.srikanth.9        O
# 44                            promote        O
# 45                               your        O
# 46                           business        O
# 47                             online        O
# 48                               pybo        O

# %% [markdown]
# # Creating BBOX

# %%
bbox = data_info.query("label != 'O' ")
image = img.copy()

for x, y, w, h, label in bbox[['left', 'top', 'width', 'height', 'label']].values:
    x = int(x)
    y = int(y)
    w = int(w)
    h = int(h)
    cv2.rectangle(image, (x, y), (x + w, y + h), (0, 255, 0), 2)
    cv2.putText(image, str(label), (x, y), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 0), 2)

cv2.imshow('Predictions', image)
cv2.waitKey(5)
cv2.destroyAllWindows()

# %%
bbox
# Out:
#    level page_num block_num par_num line_num word_num left  top width height  \
# 1      5        1         3       1        1        3  822   53   203     28
# 5      5        1         3       2        2        3  709  136   316     31
# 6      5        1         3       3        1        1   46  170    33     14
# 7      5        1         3       3        1        2   85  151    92     42
# 8      5        1         3       3        1        3  183  170   117     14
# 9      5        1         3       3        1        4  306  170    20     14
# 10     5        1         3       3        1        5  332  170    42     14
# 11     5        1         3       3        1        6  668  163   357     46
# 12     5        1         4       1        1        1  310  228   232     30
# 13     5        1         4       1        1        2  557  227   198     32
# 14     5        1         5       1        1        1  399  271   147     25
# 15     5        1         5       1        1        2  555  271   114     25
# 20     5        1         6       1        1        1   47  396    83     30
# 21     5        1         6       1        1        2  145  395   236     32
# 22     5        1         6       1        1        3  395  395   296     32
# 23     5        1         6       1        1        4  706  395    53     32
# 24     5        1         6       1        1        5  775  396   107     30
# 40     5        1         6       3        2        1   46  506   430     27
#
#          conf                                text  end  start  \
# 1   96.644051                          8099948528   15      5
# 5   86.249245               lictsrikant@gmail.com   57     36
# 6   96.406654                                life   62     58
# 7   95.806709                           insurance   72     63
# 8   96.909729                         corporation   84     73
# 9   96.172005                                  of   87     85
# 10  96.796776                               india   93     88
# 11  91.289627              seosrikantht@gmail.com  116     94
# 12  92.664276                          thathineni  127    117
# 13  96.249886                            srikanth  136    128
# 14  96.546059                           insurance  146    137
# 15  96.382957                             advisor  154    147
# 20  96.843925                                life  183    179
# 21  96.428986                           insurance  193    184
# 22  96.263168                         corporation  205    194
# 23  95.340492                                  of  208    206
# 24  95.340492                               india  214    209
# 40  85.618164  lictsrikant8099948528.blogspot.in,  340    306
#
#                                 token    label
# 1                          8099948528  B-PHONE
# 5               lictsrikant@gmail.com  B-EMAIL
# 6                                life    B-ORG
# 7                           insurance    I-ORG
# 8                         corporation    I-ORG
# 9                                  of    I-ORG
# 10                              india    I-ORG
# 11             seosrikantht@gmail.com  B-EMAIL
# 12                         thathineni   B-NAME
# 13                           srikanth   I-NAME
# 14                          insurance    B-DES
# 15                            advisor    I-DES
# 20                               life    B-ORG
# 21                          insurance    I-ORG
# 22                        corporation    I-ORG
# 23                                 of    I-ORG
# 24                              india    I-ORG
# 40  lictsrikant8099948528.blogspot.in  I-EMAIL

# %%
bbox['label'] = bbox['label'].apply(lambda x: x[2:])
bbox.head(10)
# Out:
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/2136516512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbox['label'] = bbox['label'].apply(lambda x: x[2:])
#    level page_num block_num par_num line_num word_num left  top width height  \
# 1      5        1         3       1        1        3  822   53   203     28
# 5      5        1         3       2        2        3  709  136   316     31
# 6      5        1         3       3        1        1   46  170    33     14
# 7      5        1         3       3        1        2   85  151    92     42
# 8      5        1         3       3        1        3  183  170   117     14
# 9      5        1         3       3        1        4  306  170    20     14
# 10     5        1         3       3        1        5  332  170    42     14
# 11     5        1         3       3        1        6  668  163   357     46
# 12     5        1         4       1        1        1  310  228   232     30
# 13     5        1         4       1        1        2  557  227   198     32
#
#          conf                    text  end  start                   token  \
# 1   96.644051              8099948528   15      5              8099948528
# 5   86.249245   lictsrikant@gmail.com   57     36   lictsrikant@gmail.com
# 6   96.406654                    life   62     58                    life
# 7   95.806709               insurance   72     63               insurance
# 8   96.909729             corporation   84     73             corporation
# 9   96.172005                      of   87     85                      of
# 10  96.796776                   india   93     88                   india
# 11  91.289627  seosrikantht@gmail.com  116     94  seosrikantht@gmail.com
# 12  92.664276              thathineni  127    117              thathineni
# 13  96.249886                srikanth  136    128                srikanth
#
#     label
# 1   PHONE
# 5   EMAIL
# 6     ORG
# 7     ORG
# 8     ORG
# 9     ORG
# 10    ORG
# 11  EMAIL
# 12   NAME
# 13   NAME

# %%
# grouping labels

class GroupGen:
    def __init__(self):
        self.id = 0
        self.text = ''

    def getgroup(self, text):
        if self.text == text:
            return self.id
        else:
            self.id += 1
            self.text = text
            return self.id

grp_gen = GroupGen()

# %%
bbox['group'] = bbox['label'].apply(grp_gen.getgroup)

bbox
# Out:
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/1103313996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbox['group'] = bbox['label'].apply(grp_gen.getgroup)
#    level page_num block_num par_num line_num word_num left  top width height  \
# 1      5        1         3       1        1        3  822   53   203     28
# 5      5        1         3       2        2        3  709  136   316     31
# 6      5        1         3       3        1        1   46  170    33     14
# 7      5        1         3       3        1        2   85  151    92     42
# 8      5        1         3       3        1        3  183  170   117     14
# 9      5        1         3       3        1        4  306  170    20     14
# 10     5        1         3       3        1        5  332  170    42     14
# 11     5        1         3       3        1        6  668  163   357     46
# 12     5        1         4       1        1        1  310  228   232     30
# 13     5        1         4       1        1        2  557  227   198     32
# 14     5        1         5       1        1        1  399  271   147     25
# 15     5        1         5       1        1        2  555  271   114     25
# 20     5        1         6       1        1        1   47  396    83     30
# 21     5        1         6       1        1        2  145  395   236     32
# 22     5        1         6       1        1        3  395  395   296     32
# 23     5        1         6       1        1        4  706  395    53     32
# 24     5        1         6       1        1        5  775  396   107     30
# 40     5        1         6       3        2        1   46  506   430     27
#
#          conf                                text  end  start  \
# 1   96.644051                          8099948528   15      5
# 5   86.249245               lictsrikant@gmail.com   57     36
# 6   96.406654                                life   62     58
# 7   95.806709                           insurance   72     63
# 8   96.909729                         corporation   84     73
# 9   96.172005                                  of   87     85
# 10  96.796776                               india   93     88
# 11  91.289627              seosrikantht@gmail.com  116     94
# 12  92.664276                          thathineni  127    117
# 13  96.249886                            srikanth  136    128
# 14  96.546059                           insurance  146    137
# 15  96.382957                             advisor  154    147
# 20  96.843925                                life  183    179
# 21  96.428986                           insurance  193    184
# 22  96.263168                         corporation  205    194
# 23  95.340492                                  of  208    206
# 24  95.340492                               india  214    209
# 40  85.618164  lictsrikant8099948528.blogspot.in,  340    306
#
#                                 token  label  group
# 1                          8099948528  PHONE      1
# 5               lictsrikant@gmail.com  EMAIL      2
# 6                                life    ORG      3
# 7                           insurance    ORG      3
# 8                         corporation    ORG      3
# 9                                  of    ORG      3
# 10                              india    ORG      3
# 11             seosrikantht@gmail.com  EMAIL      4
# 12                         thathineni   NAME      5
# 13                           srikanth   NAME      5
# 14                          insurance    DES      6
# 15                            advisor    DES      6
# 20                               life    ORG      7
# 21                          insurance    ORG      7
# 22                        corporation    ORG      7
# 23                                 of    ORG      7
# 24                              india    ORG      7
# 40  lictsrikant8099948528.blogspot.in  EMAIL      8

# %%
# right and bottom of bbox
bbox[['left', 'top', 'width', 'height']] = bbox[['left', 'top', 'width', 'height']].astype(int)
bbox['right'] = bbox['left'] + bbox['width']
bbox['bottom'] = bbox['top'] + bbox['height']
# Out:
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/2498645715.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbox[['left', 'top', 'width', 'height']] = bbox[['left', 'top', 'width', 'height']].astype(int)
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/2498645715.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbox['right'] = bbox['left'] + bbox['width']
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/2498645715.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   bbox['bottom'] = bbox['top'] + bbox['height']

# %%
# tagging : group by groups
columns_group = ['left', 'top', 'right', 'bottom', 'label', 'token', 'group']
group_tag_img = bbox[columns_group].groupby(by='group')
img_tagging = group_tag_img.agg({
    'left': min, 
    'right': max, 
    'top': min, 
    'bottom': max, 
    'label': np.unique, 
    'token': lambda x: " ".join(x)})

img_tagging
# Out:
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/179231619.py:4: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   img_tagging = group_tag_img.agg({
# /var/folders/qw/qx57jwkd7bxgh83_f_58kdwc0000gn/T/ipykernel_3629/179231619.py:4: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   img_tagging = group_tag_img.agg({
#        left  right  top  bottom    label                                token
# group
# 1       822   1025   53      81  [PHONE]                           8099948528
# 2       709   1025  136     167  [EMAIL]                lictsrikant@gmail.com
# 3        46    374  151     193    [ORG]  life insurance corporation of india
# 4       668   1025  163     209  [EMAIL]               seosrikantht@gmail.com
# 5       310    755  227     259   [NAME]                  thathineni srikanth
# 6       399    669  271     296    [DES]                    insurance advisor
# 7        47    882  395     427    [ORG]  life insurance corporation of india
# 8        46    476  506     533  [EMAIL]    lictsrikant8099948528.blogspot.in

# %%
img_bb = img.copy()
for l, r, t, b, label, token in img_tagging.values:
    cv2.rectangle(img_bb, (l, t), (r, b), (0, 255, 0), 2)
    cv2.putText(img_bb, str(label), (l, t), cv2.FONT_HERSHEY_PLAIN, 1, (255, 0, 255), 2)

cv2.imshow('BBOX for business card', img_bb)
cv2.waitKeyEx(0)
cv2.destroyAllWindows()
# Out:
# 2023-12-07 00:24:27.327 python[3629:191997] IMKClient Stall detected, *please Report* your user scenario attaching a spindump (or sysdiagnose) that captures the problem - (imkxpc_bundleIdentifierWithReply:) block performed very slowly (12.96 secs).

# %% [markdown]
# # Parser

# %%
def parser(text, label):
    if label == "PHONE":
        text = text.lower()
        text = re.sub(r'\D', '', text)
    elif label == "EMAIL":
        text = text.lower()
        allow_special_char = "@_.\-"
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char), '', text)
    elif label == "WEB":
        text == text.lower()
        allow_special_char = ":/.%#\-"
        text = re.sub(r'[^A-Za-z0-9{} ]'.format(allow_special_char), '', text)
    elif label in ("DES", "NAME"):
        text == text.lower()
        text = re.sub(r'[^A-Za-z ]', '', text)
        text = text.title()
    elif label == "ORG":
        text == text.lower()
        text = re.sub(r'[^a-z0-9 ]', '', text)
        text = text.title()
    return text

# %%
parser("Anton_1988@sdsd.ry", "EMAIL")
# Out:
# 'anton_1988@sdsd.ry'

# %% [markdown]
# # Entities

# %%
info_array = data_info[['token', 'label']].values
entities = dict(
    NAME=[], ORG=[], DES=[], PHONE=[], EMAIL=[], WEB=[])
previous = "O"

for token, label in info_array:
    bio_tag = label[0]
    label_tag = label[2:]
    text = parser(token, label_tag)
    if bio_tag in ('B', 'I'):
        if previous != label_tag:
            entities[label_tag].append(text)
        else:
            if bio_tag == "B":
                entities[label_tag].append(text)
            else:
                if label_tag in ("NAME", "ORG", "DES"):
                    entities[label_tag][-1] += " " + text
                else:
                    entities[label_tag][-1] += + text
    previous = label_tag

# %%
entities
# Out:
# {'NAME': ['Thathineni Srikanth'],
#  'ORG': ['Life Insurance Corporation Of India',
#   'Life Insurance Corporation Of India'],
#  'DES': ['Insurance Advisor'],
#  'PHONE': ['8099948528'],
#  'EMAIL': ['lictsrikant@gmail.com',
#   'seosrikantht@gmail.com',
#   'lictsrikant8099948528.blogspot.in'],
#  'WEB': []}

# %%
#jupyter nbconvert --to script 'predict.ipynb'
